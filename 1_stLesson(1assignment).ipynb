# %%
#-----------1_st-----------------
my_list = list()
x = 10
for i in range(x):
  my_list.append(i)
  if not i % 2 and i != 0:
    print(my_list[i])
#----------1_st------------------
# Out:
# 2
# 4
# 6
# 8

# %%
#----------2_nd------------------
my_dict = {
    'BULGARIA'                :	'SOFIA',
    'BURKINA FASO'            :	'OUAGADOUGOU',
    'BURUNDI'                 :	'BUJUMBURA',
    'CABO VERDE'	            : 'PRAIA',
    'CAMBODIA'	              : 'PHNOM PENH',
    'CAMEROON'	              : 'YAOUNDE',
    'CANADA'	                : '',
    'CENTRAL AFRICAN REPUBLIC':	'BANGUI',
    'CHAD'	                  : 'N\'DJAMENA',
    'CHILE'	                  : 'SANTIAGO',
    'CHINA'	                  : 'BEIJING',
    'COLOMBIA'	              : 'BOGOTÁ',
    'COMOROS'	                : 'MORONI'
}

for key, value in my_dict.items():
  if value:
    print(f'Key:{key}\tValue:{value}')

#----------2_nd------------------
# Out:
# Key:BULGARIA	Value:SOFIA
# Key:BURKINA FASO	Value:OUAGADOUGOU
# Key:BURUNDI	Value:BUJUMBURA
# Key:CABO VERDE	Value:PRAIA
# Key:CAMBODIA	Value:PHNOM PENH
# Key:CAMEROON	Value:YAOUNDE
# Key:CENTRAL AFRICAN REPUBLIC	Value:BANGUI
# Key:CHAD	Value:N'DJAMENA
# Key:CHILE	Value:SANTIAGO
# Key:CHINA	Value:BEIJING
# Key:COLOMBIA	Value:BOGOTÁ
# Key:COMOROS	Value:MORONI

# %%
#----------3_rd------------------
x = 100
for i in range(1,x+1):
  if i % 15 == 0 : print("%d :FizzBuzz" % (i))
  elif i % 3 == 0:print("%d :Fizz" % (i))
  elif i % 5 == 0:print("%d :Buzz" % (i))
  else : print (i)


#----------3_rd------------------
# Out:
# 1
# 2
# 3 :Fizz
# 4
# 5 :Buzz
# 6 :Fizz
# 7
# 8
# 9 :Fizz
# 10 :Buzz
# 11
# 12 :Fizz
# 13
# 14
# 15 :FizzBuzz
# 16
# 17
# 18 :Fizz
# 19
# 20 :Buzz
# 21 :Fizz
# 22
# 23
# 24 :Fizz
# 25 :Buzz
# 26
# 27 :Fizz
# 28
# 29
# 30 :FizzBuzz
# 31
# 32
# 33 :Fizz
# 34
# 35 :Buzz
# 36 :Fizz
# 37
# 38
# 39 :Fizz
# 40 :Buzz
# 41
# 42 :Fizz
# 43
# 44
# 45 :FizzBuzz
# 46
# 47
# 48 :Fizz
# 49
# 50 :Buzz
# 51 :Fizz
# 52
# 53
# 54 :Fizz
# 55 :Buzz
# 56
# 57 :Fizz
# 58
# 59
# 60 :FizzBuzz
# 61
# 62
# 63 :Fizz
# 64
# 65 :Buzz
# 66 :Fizz
# 67
# 68
# 69 :Fizz
# 70 :Buzz
# 71
# 72 :Fizz
# 73
# 74
# 75 :FizzBuzz
# 76
# 77
# 78 :Fizz
# 79
# 80 :Buzz
# 81 :Fizz
# 82
# 83
# 84 :Fizz
# 85 :Buzz
# 86
# 87 :Fizz
# 88
# 89
# 90 :FizzBuzz
# 91
# 92
# 93 :Fizz
# 94
# 95 :Buzz
# 96 :Fizz
# 97
# 98
# 99 :Fizz
# 100 :Buzz

# %%
#----------4_th------------------
def bank(summ,years,percent):
  '''сумма депозита - summ, кол-во лет - years, процент - percent.'''
  total = summ * years * percent/100 
  return total+summ

bank(100,2,5)
#----------4_th------------------
# Out:
# 110.0
